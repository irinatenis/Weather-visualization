# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude

from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
#url = https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={weather_api_key}
#print(json.dumps(places_data, indent=4, sort_keys=True))
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
# Group cities in sets of 50 for logging purposes
     if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
# Create endpoint URL with each city
     city_coordinates = f"http://api.openweathermap.org/geo/1.0/direct?q={city}&limit=1&appid={weather_api_key}"
     city_coordinates_response = requests.get(city_coordinates).json()
    
# Log the url, record, and set numbers
     print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
# Add 1 to the record count
     record_count += 1
# Run an API request for each of the cities
    
     try:
        
        city_url = f"https://api.openweathermap.org/data/2.5/weather?lat={city_coordinates_response[0]['lat']}&lon={city_coordinates_response[0]['lon']}&appid={weather_api_key}&units=metric"
        response= requests.get(city_url)
# Log the url, record, and set numbers
        data = response.json()
# Parse the JSON and retrieve data
        city_weather = data['weather']

# Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = data['coord']['lat']
        city_lng = data['coord']['lon']
        city_max_temp = data['main']['temp_max']
        city_humidity = data['main']['humidity']
        city_clouds = data['clouds']["all"]
        city_wind = data['wind']["speed"]
        city_country = data['sys']['country']
        city_date = data['dt']

# Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city
     except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | palabuhanratu
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | angelholm
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | sabha
# Processing Record 7 of Set 1 | fenoarivo
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | dingle
# Processing Record 10 of Set 1 | riviere-au-renard
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | nemuro
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | enterprise
# Processing Record 15 of Set 1 | korla
# Processing Record 16 of Set 1 | burica
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | tambilil
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | hoi an
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | port blair
# Processing Record 23 of Set 1 | hegang
# Processing Record 24 of Set 1 | chapais
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | repatriacion
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | sinnamary
# Processing Record 30 of Set 1 | niceville
# Processing Record 31 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 1 | whitewater
# Processing Record 33 of Set 1 | araguacu
# Processing Record 34 of Set 1 | kalmunai
# Processing Record 35 of Set 1 | chapleau
# Processing Record 36 of Set 1 | umm kaddadah
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | ormskirk
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | myitkyina
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | ahuimanu
# Processing Record 45 of Set 1 | nizhneyansk
# Processing Record 46 of Set 1 | skibbereen
# Processing Record 47 of Set 1 | saint anthony
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | puerto quijarro
# Processing Record 50 of Set 1 | ilan
# Processing Record 0 of Set 2 | atuona
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | mareeba
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | bacabal
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | vaitupu
# Processing Record 9 of Set 2 | bonthe
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | ancud
# Processing Record 12 of Set 2 | sumbawa
# Processing Record 13 of Set 2 | dickinson
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | mugumu
# Processing Record 16 of Set 2 | norman wells
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | olinda
# Processing Record 19 of Set 2 | malibu
# Processing Record 20 of Set 2 | baragua
# Processing Record 21 of Set 2 | amderma
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | tsihombe
# Processing Record 24 of Set 2 | katsina
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | ransang
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | omsukchan
# Processing Record 32 of Set 2 | apatity
# Processing Record 33 of Set 2 | soure
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | half moon bay
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | port macquarie
# Processing Record 39 of Set 2 | marawi
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | farafangana
# Processing Record 44 of Set 2 | moa
# Processing Record 45 of Set 2 | venado tuerto
# Processing Record 46 of Set 2 | namatanai
# Processing Record 47 of Set 2 | karaton
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | butaritari
# Processing Record 0 of Set 3 | bathsheba
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | ouallam
# Processing Record 3 of Set 3 | flin flon
# Processing Record 4 of Set 3 | sao joao da barra
# Processing Record 5 of Set 3 | taos
# Processing Record 6 of Set 3 | marathon
# Processing Record 7 of Set 3 | gigmoto
# Processing Record 8 of Set 3 | pangnirtung
# Processing Record 9 of Set 3 | vicuna
# Processing Record 10 of Set 3 | kapaa
# Processing Record 11 of Set 3 | touros
# Processing Record 12 of Set 3 | te anau
# Processing Record 13 of Set 3 | mehamn
# Processing Record 14 of Set 3 | tocopilla
# Processing Record 15 of Set 3 | pevek
# Processing Record 16 of Set 3 | kaeo
# Processing Record 17 of Set 3 | paita
# Processing Record 18 of Set 3 | hobart
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | orange cove
# Processing Record 22 of Set 3 | falealupo
# Processing Record 23 of Set 3 | santarem
# Processing Record 24 of Set 3 | coihaique
# Processing Record 25 of Set 3 | eyl
# Processing Record 26 of Set 3 | port augusta
# Processing Record 27 of Set 3 | mecca
# Processing Record 28 of Set 3 | port moresby
# Processing Record 29 of Set 3 | ambilobe
# Processing Record 30 of Set 3 | vallenar
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | ahipara
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | victoria
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | dunedin
# Processing Record 38 of Set 3 | caronport
# Processing Record 39 of Set 3 | matara
# Processing Record 40 of Set 3 | olafsvik
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | gizo
# Processing Record 43 of Set 3 | sarangani
# Processing Record 44 of Set 3 | kailua
# Processing Record 45 of Set 3 | nijar
# Processing Record 46 of Set 3 | del rio
# Processing Record 47 of Set 3 | weymouth
# Processing Record 48 of Set 3 | illoqqortoormiut
# Processing Record 49 of Set 3 | barrow
# Processing Record 0 of Set 4 | knin
# Processing Record 1 of Set 4 | obo
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | warragul
# Processing Record 4 of Set 4 | samarai
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | sabang
# Processing Record 7 of Set 4 | makakilo city
# Processing Record 8 of Set 4 | wana
# Processing Record 9 of Set 4 | dzheyrakh
# Processing Record 10 of Set 4 | fairmont
# Processing Record 11 of Set 4 | novikovo
# Processing Record 12 of Set 4 | iralaya
# Processing Record 13 of Set 4 | morro bay
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | geraldton
# Processing Record 16 of Set 4 | labuhan
# Processing Record 17 of Set 4 | bhusawal
# Processing Record 18 of Set 4 | alta gracia
# Processing Record 19 of Set 4 | batagay
# Processing Record 20 of Set 4 | isla vista
# Processing Record 21 of Set 4 | tokur
# Processing Record 22 of Set 4 | sagauli
# Processing Record 23 of Set 4 | mercedes
# Processing Record 24 of Set 4 | sembe
# Processing Record 25 of Set 4 | rapid valley
# Processing Record 26 of Set 4 | luderitz
# Processing Record 27 of Set 4 | gombe
# Processing Record 28 of Set 4 | lujan
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | barahona
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | aden
# Processing Record 34 of Set 4 | rorvik
# Processing Record 35 of Set 4 | la ronge
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | comodoro rivadavia
# Processing Record 38 of Set 4 | beringovskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | dien bien
# Processing Record 40 of Set 4 | mamurras
# Processing Record 41 of Set 4 | dikson
# Processing Record 42 of Set 4 | ucluelet
# Processing Record 43 of Set 4 | itoman
# Processing Record 44 of Set 4 | linhai
# Processing Record 45 of Set 4 | belmonte
# Processing Record 46 of Set 4 | vila franca do campo
# Processing Record 47 of Set 4 | port hawkesbury
# Processing Record 48 of Set 4 | talnakh
# Processing Record 49 of Set 4 | asau
# Processing Record 0 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 5 | aflu
# Processing Record 2 of Set 5 | goderich
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | biltine
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | san cristobal
# Processing Record 8 of Set 5 | bara
# Processing Record 9 of Set 5 | timra
# Processing Record 10 of Set 5 | gobabis
# Processing Record 11 of Set 5 | amapa
# Processing Record 12 of Set 5 | mackay
# Processing Record 13 of Set 5 | pierre
# Processing Record 14 of Set 5 | oranjemund
# Processing Record 15 of Set 5 | fare
# Processing Record 16 of Set 5 | sucua
# Processing Record 17 of Set 5 | palmer
# Processing Record 18 of Set 5 | kankon
# City not found. Skipping...
# Processing Record 19 of Set 5 | duldurga
# Processing Record 20 of Set 5 | abu kamal
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | san juan
# Processing Record 23 of Set 5 | vuktyl
# Processing Record 24 of Set 5 | cherskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | wanning
# Processing Record 26 of Set 5 | attawapiskat
# Processing Record 27 of Set 5 | pochutla
# Processing Record 28 of Set 5 | mataram
# Processing Record 29 of Set 5 | barentsburg
# Processing Record 30 of Set 5 | bramming
# Processing Record 31 of Set 5 | nikolskoye
# Processing Record 32 of Set 5 | aswan
# Processing Record 33 of Set 5 | mogoytuy
# Processing Record 34 of Set 5 | road town
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | lasa
# Processing Record 37 of Set 5 | bengkulu
# Processing Record 38 of Set 5 | roebourne
# Processing Record 39 of Set 5 | hudson bay
# Processing Record 40 of Set 5 | dhidhdhoo
# Processing Record 41 of Set 5 | madimba
# Processing Record 42 of Set 5 | ostrovnoy
# Processing Record 43 of Set 5 | lazaro cardenas
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 5 | thompson
# Processing Record 47 of Set 5 | verkhoyansk
# Processing Record 48 of Set 5 | yumen
# Processing Record 49 of Set 5 | auki
# Processing Record 0 of Set 6 | isangel
# Processing Record 1 of Set 6 | khor
# Processing Record 2 of Set 6 | ilulissat
# Processing Record 3 of Set 6 | baoding
# Processing Record 4 of Set 6 | revelstoke
# Processing Record 5 of Set 6 | kieta
# Processing Record 6 of Set 6 | eston
# Processing Record 7 of Set 6 | tual
# Processing Record 8 of Set 6 | klaksvik
# Processing Record 9 of Set 6 | mustafakemalpasa
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | kruisfontein
# Processing Record 13 of Set 6 | iskateley
# Processing Record 14 of Set 6 | ribeira grande
# Processing Record 15 of Set 6 | tiarei
# Processing Record 16 of Set 6 | staryy nadym
# City not found. Skipping...
# Processing Record 17 of Set 6 | roald
# Processing Record 18 of Set 6 | mae chan
# Processing Record 19 of Set 6 | mogadishu
# Processing Record 20 of Set 6 | nuuk
# Processing Record 21 of Set 6 | behbahan
# Processing Record 22 of Set 6 | cockburn town
# Processing Record 23 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | pangai
# Processing Record 25 of Set 6 | haines junction
# Processing Record 26 of Set 6 | sozimskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | ciras
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | new corella
# Processing Record 30 of Set 6 | vao
# Processing Record 31 of Set 6 | tura
# Processing Record 32 of Set 6 | qabis
# Processing Record 33 of Set 6 | saint-pierre
# Processing Record 34 of Set 6 | vanavara
# Processing Record 35 of Set 6 | veseloyarsk
# Processing Record 36 of Set 6 | xuddur
# Processing Record 37 of Set 6 | atambua
# Processing Record 38 of Set 6 | ugoofaaru
# City not found. Skipping...
# Processing Record 39 of Set 6 | malinyi
# Processing Record 40 of Set 6 | berdigestyakh
# Processing Record 41 of Set 6 | zlobin
# Processing Record 42 of Set 6 | jumla
# Processing Record 43 of Set 6 | mocambique
# Processing Record 44 of Set 6 | kavieng
# Processing Record 45 of Set 6 | nome
# Processing Record 46 of Set 6 | grindavik
# Processing Record 47 of Set 6 | tamandare
# Processing Record 48 of Set 6 | akhmim
# Processing Record 49 of Set 6 | louisbourg
# Processing Record 0 of Set 7 | nizwa
# Processing Record 1 of Set 7 | bambous virieux
# Processing Record 2 of Set 7 | muros
# Processing Record 3 of Set 7 | narsaq
# Processing Record 4 of Set 7 | ossora
# Processing Record 5 of Set 7 | booue
# Processing Record 6 of Set 7 | alice springs
# Processing Record 7 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 7 | mezen
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | ayer itam
# Processing Record 11 of Set 7 | kazalinsk
# Processing Record 12 of Set 7 | saint-paul
# Processing Record 13 of Set 7 | fairbanks
# Processing Record 14 of Set 7 | chicama
# Processing Record 15 of Set 7 | leh
# Processing Record 16 of Set 7 | atagay
# Processing Record 17 of Set 7 | eyrarbakki
# Processing Record 18 of Set 7 | kenai
# Processing Record 19 of Set 7 | dentsville
# Processing Record 20 of Set 7 | sampit
# Processing Record 21 of Set 7 | bilma
# Processing Record 22 of Set 7 | shubarshi
# Processing Record 23 of Set 7 | richards bay
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | christchurch
# Processing Record 26 of Set 7 | kiruna
# Processing Record 27 of Set 7 | la orilla
# Processing Record 28 of Set 7 | valparaiso
# Processing Record 29 of Set 7 | sao felix do xingu
# Processing Record 30 of Set 7 | messina
# Processing Record 31 of Set 7 | upernavik
# Processing Record 32 of Set 7 | dakar
# Processing Record 33 of Set 7 | wajir
# Processing Record 34 of Set 7 | cabra
# Processing Record 35 of Set 7 | iqaluit
# Processing Record 36 of Set 7 | tarko-sale
# Processing Record 37 of Set 7 | aki
# Processing Record 38 of Set 7 | san andres
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | otta
# Processing Record 41 of Set 7 | saint-augustin
# Processing Record 42 of Set 7 | ciudad bolivar
# Processing Record 43 of Set 7 | upata
# Processing Record 44 of Set 7 | togur
# Processing Record 45 of Set 7 | maues
# Processing Record 46 of Set 7 | palmas de monte alto
# Processing Record 47 of Set 7 | yulara
# Processing Record 48 of Set 7 | tarakan
# Processing Record 49 of Set 7 | anamur
# Processing Record 0 of Set 8 | sorland
# Processing Record 1 of Set 8 | yanan
# Processing Record 2 of Set 8 | sao gabriel da cachoeira
# Processing Record 3 of Set 8 | smithers
# Processing Record 4 of Set 8 | gasa
# Processing Record 5 of Set 8 | otane
# Processing Record 6 of Set 8 | aloleng
# Processing Record 7 of Set 8 | shingu
# Processing Record 8 of Set 8 | srednekolymsk
# Processing Record 9 of Set 8 | warrnambool
# Processing Record 10 of Set 8 | codrington
# Processing Record 11 of Set 8 | deputatskiy
# Processing Record 12 of Set 8 | wuda
# Processing Record 13 of Set 8 | yurgamysh
# Processing Record 14 of Set 8 | coetupo
# City not found. Skipping...
# Processing Record 15 of Set 8 | bargal
# Processing Record 16 of Set 8 | grand river south east
# Processing Record 17 of Set 8 | hurricane
# Processing Record 18 of Set 8 | hay river
# Processing Record 19 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 8 | nakapiripirit
# Processing Record 21 of Set 8 | coari
# Processing Record 22 of Set 8 | vkhodnoy
# City not found. Skipping...
# Processing Record 23 of Set 8 | mandan
# Processing Record 24 of Set 8 | nouadhibou
# Processing Record 25 of Set 8 | pedernales
# Processing Record 26 of Set 8 | sangueya
# City not found. Skipping...
# Processing Record 27 of Set 8 | bud
# Processing Record 28 of Set 8 | lavrentiya
# Processing Record 29 of Set 8 | krasnoarmeysk
# Processing Record 30 of Set 8 | general roca
# Processing Record 31 of Set 8 | alice town
# Processing Record 32 of Set 8 | sorvag
# Processing Record 33 of Set 8 | lianzhou
# Processing Record 34 of Set 8 | foshan
# Processing Record 35 of Set 8 | solnechnyy
# Processing Record 36 of Set 8 | high level
# Processing Record 37 of Set 8 | kirakira
# Processing Record 38 of Set 8 | leningradskiy
# Processing Record 39 of Set 8 | faya
# Processing Record 40 of Set 8 | urumqi
# Processing Record 41 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 8 | lucapa
# Processing Record 43 of Set 8 | hualmay
# Processing Record 44 of Set 8 | paamiut
# Processing Record 45 of Set 8 | pilar
# Processing Record 46 of Set 8 | taltal
# Processing Record 47 of Set 8 | korcula
# Processing Record 48 of Set 8 | port hedland
# Processing Record 49 of Set 8 | pisco
# Processing Record 0 of Set 9 | hambantota
# Processing Record 1 of Set 9 | vila velha
# Processing Record 2 of Set 9 | shitanjing
# Processing Record 3 of Set 9 | hollister
# Processing Record 4 of Set 9 | qaqortoq
# Processing Record 5 of Set 9 | yemelyanovo
# Processing Record 6 of Set 9 | mys shmidta
# Processing Record 7 of Set 9 | silifke
# Processing Record 8 of Set 9 | canterbury
# Processing Record 9 of Set 9 | salinopolis
# Processing Record 10 of Set 9 | yushala
# City not found. Skipping...
# Processing Record 11 of Set 9 | nanortalik
# Processing Record 12 of Set 9 | vila
# Processing Record 13 of Set 9 | santa rosa
# Processing Record 14 of Set 9 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 15 of Set 9 | jinchengjiang
# Processing Record 16 of Set 9 | hami
# Processing Record 17 of Set 9 | aranjuez
# Processing Record 18 of Set 9 | pangkalanbuun
# City not found. Skipping...
# Processing Record 19 of Set 9 | albanel
# Processing Record 20 of Set 9 | leeds
# Processing Record 21 of Set 9 | arlit
# Processing Record 22 of Set 9 | manzil salim
# City not found. Skipping...
# Processing Record 23 of Set 9 | tbilisskaya
# Processing Record 24 of Set 9 | port hardy
# Processing Record 25 of Set 9 | arcata
# Processing Record 26 of Set 9 | boa vista
# Processing Record 27 of Set 9 | vostok
# City not found. Skipping...
# Processing Record 28 of Set 9 | pakokku
# Processing Record 29 of Set 9 | kaitangata
# Processing Record 30 of Set 9 | rodrigues alves
# Processing Record 31 of Set 9 | mount gambier
# Processing Record 32 of Set 9 | derzhavinsk
# Processing Record 33 of Set 9 | maltahohe
# Processing Record 34 of Set 9 | husavik
# Processing Record 35 of Set 9 | tabou
# Processing Record 36 of Set 9 | san quintin
# Processing Record 37 of Set 9 | bonavista
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | jatai
# Processing Record 40 of Set 9 | charters towers
# Processing Record 41 of Set 9 | yakima
# Processing Record 42 of Set 9 | innisfail
# Processing Record 43 of Set 9 | algemesi
# Processing Record 44 of Set 9 | qandahar
# Processing Record 45 of Set 9 | akodia
# Processing Record 46 of Set 9 | nalut
# Processing Record 47 of Set 9 | padang
# Processing Record 48 of Set 9 | nishihara
# Processing Record 49 of Set 9 | maceio
# Processing Record 0 of Set 10 | port lincoln
# Processing Record 1 of Set 10 | puerto narino
# Processing Record 2 of Set 10 | darhan
# Processing Record 3 of Set 10 | alcudia
# Processing Record 4 of Set 10 | el fuerte
# Processing Record 5 of Set 10 | cayenne
# Processing Record 6 of Set 10 | bereda
# Processing Record 7 of Set 10 | samusu
# Processing Record 8 of Set 10 | saurimo
# Processing Record 9 of Set 10 | chikoy
# Processing Record 10 of Set 10 | bardiyah
# City not found. Skipping...
# Processing Record 11 of Set 10 | takaka
# Processing Record 12 of Set 10 | port-gentil
# Processing Record 13 of Set 10 | west bay
# Processing Record 14 of Set 10 | port keats
# Processing Record 15 of Set 10 | malwan
# Processing Record 16 of Set 10 | amahai
# Processing Record 17 of Set 10 | jimma
# Processing Record 18 of Set 10 | humaita
# Processing Record 19 of Set 10 | gawler
# Processing Record 20 of Set 10 | mayo
# Processing Record 21 of Set 10 | kaduqli
# Processing Record 22 of Set 10 | turukhansk
# Processing Record 23 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 10 | union
# Processing Record 25 of Set 10 | mizdah
# City not found. Skipping...
# Processing Record 26 of Set 10 | terre haute
# Processing Record 27 of Set 10 | saint-francois
# Processing Record 28 of Set 10 | progreso
# Processing Record 29 of Set 10 | lorengau
# Processing Record 30 of Set 10 | arco
# Processing Record 31 of Set 10 | kununurra
# Processing Record 32 of Set 10 | portland
# Processing Record 33 of Set 10 | lazi
# Processing Record 34 of Set 10 | anadyr
# Processing Record 35 of Set 10 | yar-sale
# City not found. Skipping...
# Processing Record 36 of Set 10 | la palma
# Processing Record 37 of Set 10 | muroto
# Processing Record 38 of Set 10 | chandbali
# Processing Record 39 of Set 10 | hovd
# Processing Record 40 of Set 10 | komsomolskiy
# Processing Record 41 of Set 10 | conway
# Processing Record 42 of Set 10 | souillac
# Processing Record 43 of Set 10 | villamontes
# Processing Record 44 of Set 10 | plover
# Processing Record 45 of Set 10 | saldanha
# Processing Record 46 of Set 10 | corinto
# Processing Record 47 of Set 10 | zhaozhou
# Processing Record 48 of Set 10 | broome
# Processing Record 49 of Set 10 | chengde
# Processing Record 0 of Set 11 | tateyama
# Processing Record 1 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 2 of Set 11 | jibuti
# Processing Record 3 of Set 11 | kushima
# Processing Record 4 of Set 11 | nantucket
# Processing Record 5 of Set 11 | chaoyang
# Processing Record 6 of Set 11 | banfora
# Processing Record 7 of Set 11 | mangaluru
# Processing Record 8 of Set 11 | barletta
# Processing Record 9 of Set 11 | labuan
# Processing Record 10 of Set 11 | brae
# Processing Record 11 of Set 11 | eureka
# Processing Record 12 of Set 11 | inhambane
# Processing Record 13 of Set 11 | mumbwa
# Processing Record 14 of Set 11 | cottonwood
# Processing Record 15 of Set 11 | herat
# Processing Record 16 of Set 11 | bangsund
# Processing Record 17 of Set 11 | zyryanka
# Processing Record 18 of Set 11 | keuruu
# Processing Record 19 of Set 11 | imeni tsyurupy
# Processing Record 20 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 11 | juneau
# Processing Record 22 of Set 11 | butterworth
# Processing Record 23 of Set 11 | shimoda
# Processing Record 24 of Set 11 | sitia
# Processing Record 25 of Set 11 | arman
# Processing Record 26 of Set 11 | morondava
# Processing Record 27 of Set 11 | birao
# Processing Record 28 of Set 11 | tarauaca
# Processing Record 29 of Set 11 | ambodifototra
# Processing Record 30 of Set 11 | sivas
# Processing Record 31 of Set 11 | artyk
# Processing Record 32 of Set 11 | taber
# Processing Record 33 of Set 11 | barranca
# Processing Record 34 of Set 11 | kijang
# Processing Record 35 of Set 11 | formoso do araguaia
# Processing Record 36 of Set 11 | adrar
# Processing Record 37 of Set 11 | mulchen
# Processing Record 38 of Set 11 | mandalgovi
# Processing Record 39 of Set 11 | shenzhen
# Processing Record 40 of Set 11 | sorong
# Processing Record 41 of Set 11 | kizukuri
# City not found. Skipping...
# Processing Record 42 of Set 11 | ukiah
# Processing Record 43 of Set 11 | bet shemesh
# Processing Record 44 of Set 11 | kupang
# Processing Record 45 of Set 11 | sosnovo-ozerskoye
# Processing Record 46 of Set 11 | macenta
# Processing Record 47 of Set 11 | pinsk
# Processing Record 48 of Set 11 | jiuquan
# Processing Record 49 of Set 11 | noumea
# Processing Record 0 of Set 12 | zelenogorskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | yizheng
# Processing Record 2 of Set 12 | great yarmouth
# Processing Record 3 of Set 12 | fort nelson
# Processing Record 4 of Set 12 | arroyos y esteros
# Processing Record 5 of Set 12 | vilyuysk
# Processing Record 6 of Set 12 | porto novo
# Processing Record 7 of Set 12 | guerrero negro
# Processing Record 8 of Set 12 | hobyo
# Processing Record 9 of Set 12 | sredneuralsk
# Processing Record 10 of Set 12 | marzuq
# Processing Record 11 of Set 12 | namibe
# Processing Record 12 of Set 12 | nhulunbuy
# Processing Record 13 of Set 12 | acolla
# Processing Record 14 of Set 12 | hokitika
# Processing Record 15 of Set 12 | baruun-urt
# Processing Record 16 of Set 12 | palembang
# Processing Record 17 of Set 12 | grand-santi
# Processing Record 18 of Set 12 | lepe
# Processing Record 19 of Set 12 | moron
# Processing Record 20 of Set 12 | mount isa
# Processing Record 21 of Set 12 | souris
# Processing Record 22 of Set 12 | quatre cocos
# Processing Record 23 of Set 12 | filingue
# Processing Record 24 of Set 12 | saskylakh
# Processing Record 25 of Set 12 | semnan
# Processing Record 26 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 12 | henties bay
# Processing Record 28 of Set 12 | hofn
# Processing Record 29 of Set 12 | katha
# Processing Record 30 of Set 12 | ambatondrazaka
# Processing Record 31 of Set 12 | araouane
# Processing Record 32 of Set 12 | minab
# Processing Record 33 of Set 12 | jalu
# Processing Record 34 of Set 12 | belaya gora
# Processing Record 35 of Set 12 | balabac
# Processing Record 36 of Set 12 | ilave
# Processing Record 37 of Set 12 | mapastepec
# Processing Record 38 of Set 12 | dindori
# Processing Record 39 of Set 12 | carutapera
# Processing Record 40 of Set 12 | kabanjahe
# Processing Record 41 of Set 12 | kanniyakumari
# City not found. Skipping...
# Processing Record 42 of Set 12 | veraval
# Processing Record 43 of Set 12 | constitucion
# Processing Record 44 of Set 12 | boksburg
# Processing Record 45 of Set 12 | gat
# Processing Record 46 of Set 12 | clyde river
# Processing Record 47 of Set 12 | coyutla
# Processing Record 48 of Set 12 | gari
# Processing Record 49 of Set 12 | ijaki
# Processing Record 0 of Set 13 | buraydah
# Processing Record 1 of Set 13 | grahamstown
# Processing Record 2 of Set 13 | tobermory
# Processing Record 3 of Set 13 | copiague
# Processing Record 4 of Set 13 | petropavl
# Processing Record 5 of Set 13 | balassagyarmat
# Processing Record 6 of Set 13 | shimanovsk
# Processing Record 7 of Set 13 | karratha
# Processing Record 8 of Set 13 | teknaf
# Processing Record 9 of Set 13 | lima
# Processing Record 10 of Set 13 | savannah bight
# Processing Record 11 of Set 13 | aliaga
# Processing Record 12 of Set 13 | barstow
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          vaini -21.1926 -175.1773     24.16        94          20
# 1  palabuhanratu  -6.9882  106.5504     25.47        97          99
# 2         albany  42.6512  -73.7550      8.84        38          20
# 3      angelholm  56.2429   12.8619     14.19        38           0
# 4           chuy -33.6938  -53.4561     23.19        55           0
#
#    Wind Speed Country        Date
# 0        2.06      TO  1681050233
# 1        1.65      ID  1681050220
# 2        1.54      US  1681050195
# 3        3.60      SE  1681050312
# 4        2.35      BR  1681050226

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                vaini -21.1926 -175.1773     24.16        94          20
# 1        palabuhanratu  -6.9882  106.5504     25.47        97          99
# 2               albany  42.6512  -73.7550      8.84        38          20
# 3            angelholm  56.2429   12.8619     14.19        38           0
# 4                 chuy -33.6938  -53.4561     23.19        55           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      TO  1681050233
# 1              1.65      ID  1681050220
# 2              1.54      US  1681050195
# 3              3.60      SE  1681050312
# 4              2.35      BR  1681050226

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
lat=city_data_df["Lat"]
temp=city_data_df["Max Temp"]
plt.scatter(lat,temp,color="tab:blue",edgecolor="black")
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("City Max Latitude vs. Temperature (2023-4-9)")
plt.grid()
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat=city_data_df["Lat"]
hum=city_data_df["Humidity"]
plt.scatter(lat,hum)

# Incorporate the other graph properties
plt.scatter(lat,hum,color="tab:blue",edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-4-9)")
plt.grid()
# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat=city_data_df["Lat"]
cloud=city_data_df["Cloudiness"]
plt.scatter(lat,cloud,color="tab:blue",edgecolor="black")

# Incorporate the other graph properties
plt.scatter(lat,cloud,color="tab:blue",edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-4-9)")
plt.grid()

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
lat=city_data_df["Lat"]
wind=city_data_df["Wind Speed"]
plt.scatter(lat,wind,color="tab:blue",edgecolor="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Cloudiness (2023-4-9)")
plt.grid()

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope,intercept, rvalue,pvalue,stderr) = st.linregress(x,y)
regress_values= x*slope+intercept
regress_values
#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df["Lat"]>=0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                   albany  42.6512  -73.7550      8.84        38          20
# 3                angelholm  56.2429   12.8619     14.19        38           0
# 7                  kahului  20.8894 -156.4727     22.66        88          75
# 8                   dingle  11.0001  122.6718     24.57        85         100
# 9        riviere-au-renard  48.9926  -64.3858     -1.01        62          99
#
#          Wind Speed Country        Date
# City_ID
# 2              1.54      US  1681050195
# 3              3.60      SE  1681050312
# 7              5.14      US  1681050314
# 8              2.77      PH  1681050185
# 9              7.32      CA  1681050315

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]<0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                vaini -21.1926 -175.1773     24.16        94          20
# 1        palabuhanratu  -6.9882  106.5504     25.47        97          99
# 4                 chuy -33.6938  -53.4561     23.19        55           0
# 5                sabha -18.1416  178.4422     23.71       100          20
# 6            fenoarivo -21.7185   46.3814     26.52        60          19
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      TO  1681050233
# 1              1.65      ID  1681050220
# 4              2.35      BR  1681050226
# 5              0.00      FJ  1681050313
# 6              3.82      MG  1681050313

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
n_temp = northern_hemi_df["Max Temp"]
n_lat = northern_hemi_df["Lat"]
plt.scatter(n_lat,n_temp,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
(slope,intercept, rvalue,pvalue,stderr) = linregress(n_lat,n_temp)

regress_values= n_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(n_lat,regress_values,"r-")
plt.text(7,-10, line_eq, size=12, color = "red")

print(f"The r-value is {rvalue}.")
# Out:
# The r-value is -0.8399591512683615.

# %%
# Linear regression on Southern Hemisphere
s_temp = southern_hemi_df["Max Temp"]
s_lat = southern_hemi_df["Lat"]
plt.scatter(s_lat,s_temp,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
(slope,intercept, rvalue,pvalue,stderr) = linregress(s_lat,s_temp)

regress_values= s_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(s_lat,regress_values,"r-")
plt.text(-52,30, line_eq, size=12, color = "red")

print(f"The r-value is {rvalue}.")
# Out:
# The r-value is 0.7315461665814554.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
n_hum = northern_hemi_df["Humidity"]
n_lat = northern_hemi_df["Lat"]
plt.scatter(n_lat,n_hum,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
(slope,intercept, rvalue,pvalue,stderr) = linregress(n_lat,n_hum)

regress_values= n_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(n_lat,regress_values,"r-")
plt.text(45,10, line_eq, size=12, color = "red")

print(f"The r-value is {rvalue}.")
# Out:
# The r-value is 0.2980823981370006.

# %%
# Southern Hemisphere
s_hum = southern_hemi_df["Humidity"]
s_lat = southern_hemi_df["Lat"]
plt.scatter(s_lat,s_hum,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
(slope,intercept, rvalue,pvalue,stderr) = linregress(s_lat,s_hum)

regress_values= s_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(s_lat,regress_values,"r-")
plt.text(-52,30, line_eq, size=12, color = "red")

print(f"The r-value is {rvalue}.")
# Out:
# The r-value is 0.197529830805357.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
n_cloud = northern_hemi_df["Cloudiness"]
n_lat = northern_hemi_df["Lat"]
plt.scatter(n_lat,n_cloud,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
(slope,intercept, rvalue,pvalue,stderr) = linregress(n_lat,n_cloud)

regress_values= n_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(n_lat,regress_values,"r-")
plt.text(45,10, line_eq, size=12, color = "red")

print(f"The r-value is {rvalue}.")
# Out:
# The r-value is 0.1282951164982239.

# %%
# Southern Hemisphere
s_cloud = southern_hemi_df["Cloudiness"]
s_lat = southern_hemi_df["Lat"]
plt.scatter(s_lat,s_cloud,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
(slope,intercept, rvalue,pvalue,stderr) = linregress(s_lat,s_cloud)

regress_values= s_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(s_lat,regress_values,"r-")
plt.text(-30,30, line_eq, size=12, color = "red")

print(f"The r-value is {rvalue}.")
# Out:
# The r-value is 0.20584659653339524.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
n_wind = northern_hemi_df["Wind Speed"]
n_lat = northern_hemi_df["Lat"]
plt.scatter(n_lat,n_wind,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
(slope,intercept, rvalue,pvalue,stderr) = linregress(n_lat,n_wind)

regress_values= n_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(n_lat,regress_values,"r-")
plt.text(10,12, line_eq, size=12, color = "red")
r=pearsonr(n_lat,n_wind)
print(r)#double check
print(f"The r-value is {rvalue}.")
# Out:
# PearsonRResult(statistic=0.1473230807760747, pvalue=0.002820811560279718)
# The r-value is 0.14732308077607464.

# %%
# Southern Hemisphere
s_wind = southern_hemi_df["Wind Speed"]
s_lat = southern_hemi_df["Lat"]
plt.scatter(s_lat,s_wind,color="tab:blue")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

(slope,intercept, rvalue,pvalue,stderr) = linregress(s_lat,s_wind)

regress_values= s_lat*slope+intercept
regress_values

#Create line equation string
line_eq= "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(s_lat,regress_values,"r-")
plt.text(-50,12, line_eq, size=12, color = "red")

print(f"The r-value is {rvalue}.")
# Out:
# The r-value is -0.34926508014609514.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
